# %%
from VINNCOPY import *

# %%
auc_list=[]
k=10
elbo_list=[]
for j in range(k):

    S=200 # number of sampled W
    iteration=100
  
    # cancer data
 #   x_sample,y_sample=datasets.load_breast_cancer(return_X_y=True)
#    x_sample=x_sample

  
    # artifical data
    n_sample=2000
    para_num=30
    x_sample, y_sample = datasets.make_classification(n_samples=n_sample, n_features=para_num, n_redundant=0, n_informative=para_num,
                             n_clusters_per_class=4)
    y_sample=np.reshape(y_sample,[n_sample,1])
    #x_sample+=np.random.uniform(-0.1,0.1,np.shape(x_sample))

    
    # polish bankcruptcy data    
#    data=pd.read_csv('bankruptcy.csv')
#    y_sample=data.iloc[:,-1].values.reshape([len(data),1])
#    y_sample=y_sample.astype('float64')
#    x_sample=data.iloc[:,:20].values
    
    
    x_sample=(x_sample-np.mean(x_sample,0))/np.std(x_sample,axis=0)
    n_sample=np.shape(x_sample)[0]
    
    
    B=int(n_sample/iteration) # number of observation per batch
    
    x_train, x_test, y_train, y_test = train_test_split(x_sample, y_sample, test_size=50/n_sample)
    para_num=np.shape(x_train)[1]
    
    Mrule=(para_num+1)/2
    
    M1=int(Mrule/2)
    M2=int(Mrule/2)
    M3=1
    network_structures=[para_num,M1,M2,M3]
    try:
        best_arg,elbo=batch_trainning(x_train,y_train,x_test,y_test,B,S,network_structures,epislon=3,mu=0,sigma=1.5,mu_p=0.0,sigma_p=1.8,lr=1,lr_s=0.02)
    except:
        continue
    pred_prob,auc_temp=results_plot(best_arg)
    auc_list.append(auc_temp)
    elbo_list.append(elbo)
# Out:
# logp = -234.8, ||grad|| = 0.0046571: 100%|██████████| 20/20 [00:00<00:00, 1504.76it/s]
# logp = -234.81, ||grad|| = 0.0080098: 100%|██████████| 20/20 [00:00<00:00, 1598.29it/s]
# logp = -234.8, ||grad|| = 0.0036859: 100%|██████████| 19/19 [00:00<00:00, 1566.67it/s]
# logp = -234.81, ||grad|| = 0.010561: 100%|██████████| 21/21 [00:00<00:00, 1507.01it/s]
# logp = -234.8, ||grad|| = 0.0032878: 100%|██████████| 19/19 [00:00<00:00, 1501.15it/s]
# logp = -234.8, ||grad|| = 0.0042631: 100%|██████████| 20/20 [00:00<00:00, 1549.40it/s]
# logp = -234.81, ||grad|| = 0.0070014: 100%|██████████| 21/21 [00:00<00:00, 1588.29it/s]
# logp = -56.864, ||grad|| = 0.0005165: 100%|██████████| 33/33 [00:00<00:00, 3261.13it/s]
# logp = -57.063, ||grad|| = 0.0012328: 100%|██████████| 120/120 [00:00<00:00, 3550.18it/s]
# logp = -inf, ||grad|| = 0.0010507: 100%|██████████| 22/22 [00:00<00:00, 3134.65it/s]
# logp = -58.469, ||grad|| = 0.018813: 100%|██████████| 45/45 [00:00<00:00, 3320.26it/s]
# logp = -84.967, ||grad|| = 3.1413: 100%|██████████| 65/65 [00:00<00:00, 3521.76it/s]
# logp = -58.088, ||grad|| = 0.017413: 100%|██████████| 97/97 [00:00<00:00, 3525.45it/s]
# logp = -57.36, ||grad|| = 0.0013234: 100%|██████████| 30/30 [00:00<00:00, 3291.29it/s]
# logp = -54.788, ||grad|| = 2.5509e-05: 100%|██████████| 31/31 [00:00<00:00, 3452.65it/s]
# logp = -234.8, ||grad|| = 0.0035155: 100%|██████████| 19/19 [00:00<00:00, 1539.10it/s]
# logp = -234.8, ||grad|| = 0.0049344: 100%|██████████| 20/20 [00:00<00:00, 1507.96it/s]
# logp = -234.8, ||grad|| = 0.0050147: 100%|██████████| 20/20 [00:00<00:00, 1505.87it/s]
# logp = -234.81, ||grad|| = 0.0049486: 100%|██████████| 20/20 [00:00<00:00, 1517.75it/s]
# logp = -234.8, ||grad|| = 0.0050264: 100%|██████████| 20/20 [00:00<00:00, 1509.77it/s]
# logp = -234.8, ||grad|| = 0.007494: 100%|██████████| 20/20 [00:00<00:00, 1582.16it/s]
# logp = -234.81, ||grad|| = 0.0056688: 100%|██████████| 21/21 [00:00<00:00, 1553.45it/s]
# logp = -56.371, ||grad|| = 5.7923e-05: 100%|██████████| 53/53 [00:00<00:00, 3275.83it/s]
# logp = -56.398, ||grad|| = 0.0001752: 100%|██████████| 109/109 [00:00<00:00, 3206.74it/s]
# logp = -56.567, ||grad|| = 0.0014667: 100%|██████████| 55/55 [00:00<00:00, 3120.21it/s]
# logp = -56.427, ||grad|| = 0.000963: 100%|██████████| 27/27 [00:00<00:00, 3135.36it/s]
# logp = -56.398, ||grad|| = 0.0010495: 100%|██████████| 110/110 [00:00<00:00, 3460.41it/s]
# logp = -56.413, ||grad|| = 0.00086703: 100%|██████████| 96/96 [00:00<00:00, 3471.15it/s]
# logp = -inf, ||grad|| = 1.6729: 100%|██████████| 62/62 [00:00<00:00, 3297.74it/s]
# logp = -60.923, ||grad|| = 2.216: 100%|██████████| 55/55 [00:00<00:00, 3411.62it/s]
# logp = -234.8, ||grad|| = 0.0035544: 100%|██████████| 19/19 [00:00<00:00, 1594.03it/s]
# logp = -234.8, ||grad|| = 0.0048198: 100%|██████████| 20/20 [00:00<00:00, 1542.87it/s]
# logp = -234.8, ||grad|| = 0.0042827: 100%|██████████| 20/20 [00:00<00:00, 1630.69it/s]
# logp = -234.8, ||grad|| = 0.0046307: 100%|██████████| 20/20 [00:00<00:00, 1557.95it/s]
# logp = -234.8, ||grad|| = 0.0042934: 100%|██████████| 20/20 [00:00<00:00, 1547.89it/s]
# logp = -234.8, ||grad|| = 0.0039897: 100%|██████████| 20/20 [00:00<00:00, 1626.17it/s]
# logp = -234.8, ||grad|| = 4.5934e-05: 100%|██████████| 24/24 [00:00<00:00, 1577.79it/s]
# logp = -56.174, ||grad|| = 1.8184e-05: 100%|██████████| 23/23 [00:00<00:00, 3464.00it/s]
# logp = -59.532, ||grad|| = 0.00024299: 100%|██████████| 34/34 [00:00<00:00, 3189.09it/s]
# logp = -59.532, ||grad|| = 1.987e-05: 100%|██████████| 32/32 [00:00<00:00, 3419.39it/s]
# logp = -56.18, ||grad|| = 0.0039375: 100%|██████████| 20/20 [00:00<00:00, 3388.79it/s]
# logp = -58.675, ||grad|| = 0.0051323: 100%|██████████| 25/25 [00:00<00:00, 3410.23it/s]
# logp = -58.675, ||grad|| = 6.0819e-05: 100%|██████████| 29/29 [00:00<00:00, 3338.86it/s]
# logp = -59.532, ||grad|| = 0.00024299: 100%|██████████| 34/34 [00:00<00:00, 3484.32it/s]
# logp = -54.788, ||grad|| = 2.4483e-06: 100%|██████████| 32/32 [00:00<00:00, 3283.21it/s]
# accuracy is 0.56
# logp = -234.8, ||grad|| = 3.0667e-05: 100%|██████████| 23/23 [00:00<00:00, 1452.23it/s]
# logp = -234.8, ||grad|| = 0.005827: 100%|██████████| 20/20 [00:00<00:00, 1540.66it/s]
# logp = -234.81, ||grad|| = 0.007818: 100%|██████████| 20/20 [00:00<00:00, 1575.62it/s]
# logp = -234.81, ||grad|| = 0.0056881: 100%|██████████| 20/20 [00:00<00:00, 1498.66it/s]
# logp = -234.8, ||grad|| = 0.005259: 100%|██████████| 20/20 [00:00<00:00, 1494.76it/s]
# logp = -234.81, ||grad|| = 0.0050981: 100%|██████████| 20/20 [00:00<00:00, 1522.65it/s]
# logp = -234.8, ||grad|| = 0.005799: 100%|██████████| 20/20 [00:00<00:00, 1551.32it/s]
# logp = -55.483, ||grad|| = 0.00098849: 100%|██████████| 30/30 [00:00<00:00, 2952.35it/s]
# logp = -60.099, ||grad|| = 2.1606: 100%|██████████| 51/51 [00:00<00:00, 3089.26it/s]
# logp = -57.393, ||grad|| = 0.017031: 100%|██████████| 45/45 [00:00<00:00, 2962.54it/s]
# logp = -55.483, ||grad|| = 6.188e-05: 100%|██████████| 30/30 [00:00<00:00, 3140.86it/s]
# logp = -55.482, ||grad|| = 4.4563e-05: 100%|██████████| 28/28 [00:00<00:00, 3185.17it/s]
# logp = -57.394, ||grad|| = 0.0010629: 100%|██████████| 60/60 [00:00<00:00, 3314.26it/s]
# logp = -57.396, ||grad|| = 0.019606: 100%|██████████| 50/50 [00:00<00:00, 3363.79it/s]
# logp = -54.788, ||grad|| = 4.9327e-05: 100%|██████████| 39/39 [00:00<00:00, 3343.17it/s]
# accuracy is 0.72
# logp = -234.81, ||grad|| = 0.0072086: 100%|██████████| 20/20 [00:00<00:00, 1464.39it/s]
# logp = -234.81, ||grad|| = 0.0087863: 100%|██████████| 21/21 [00:00<00:00, 1576.75it/s]
# logp = -234.8, ||grad|| = 0.0053129: 100%|██████████| 20/20 [00:00<00:00, 1543.33it/s]
# logp = -234.8, ||grad|| = 0.0051818: 100%|██████████| 20/20 [00:00<00:00, 1550.09it/s]
# logp = -234.8, ||grad|| = 0.0043382: 100%|██████████| 20/20 [00:00<00:00, 1595.88it/s]
# logp = -234.8, ||grad|| = 0.0043104: 100%|██████████| 20/20 [00:00<00:00, 1541.29it/s]
# logp = -234.8, ||grad|| = 0.004153: 100%|██████████| 19/19 [00:00<00:00, 1548.92it/s]
# logp = -56.177, ||grad|| = 0.0028502: 100%|██████████| 20/20 [00:00<00:00, 3017.38it/s]
# logp = -65.897, ||grad|| = 7.2044: 100%|██████████| 67/67 [00:00<00:00, 3327.12it/s]
# logp = -58.392, ||grad|| = 0.6522: 100%|██████████| 43/43 [00:00<00:00, 3322.62it/s]
# logp = -56.359, ||grad|| = 9.7272e-05: 100%|██████████| 79/79 [00:00<00:00, 3485.18it/s]
# logp = -58.755, ||grad|| = 0.39072: 100%|██████████| 36/36 [00:00<00:00, 3252.31it/s]
# logp = -57.636, ||grad|| = 0.0020248: 100%|██████████| 69/69 [00:00<00:00, 3253.01it/s]
# logp = -56.371, ||grad|| = 1.3287e-05: 100%|██████████| 82/82 [00:00<00:00, 3304.70it/s]
# logp = -54.904, ||grad|| = 0.013277: 100%|██████████| 90/90 [00:00<00:00, 3425.13it/s]

# %%
pd.DataFrame(elbo_list).T.plot()

# %%
sns.distplot(auc_list)

# %%
pd.DataFrame(elbo_list).to_csv('elbo_list.csv')

# %%
pd.DataFrame(auc_list).to_csv('auc_list.csv')

# %%
auc_list2=[]
k=10
elbo_list2=[]
for j in range(k):

    S=200 # number of sampled W
    iteration=100
  
    # cancer data
 #   x_sample,y_sample=datasets.load_breast_cancer(return_X_y=True)
#    x_sample=x_sample

  
    # artifical data
    n_sample=2000
    para_num=30
    x_sample, y_sample = datasets.make_classification(n_samples=n_sample, n_features=para_num, n_redundant=0, n_informative=para_num,
                             n_clusters_per_class=4)
    y_sample=np.reshape(y_sample,[n_sample,1])
    #x_sample+=np.random.uniform(-0.1,0.1,np.shape(x_sample))

    
    # polish bankcruptcy data    
#    data=pd.read_csv('bankruptcy.csv')
#    y_sample=data.iloc[:,-1].values.reshape([len(data),1])
#    y_sample=y_sample.astype('float64')
#    x_sample=data.iloc[:,:20].values
    
    
    
    x_sample=(x_sample-np.mean(x_sample,0))/np.std(x_sample,axis=0)
    n_sample=np.shape(x_sample)[0]
    
    
    B=int(n_sample/iteration) # number of observation per batch
    
    x_train, x_test, y_train, y_test = train_test_split(x_sample, y_sample, test_size=50/n_sample)
    para_num=np.shape(x_train)[1]
    
    Mrule=(para_num+1)/2
    
    M1=int(Mrule/2)
    M2=int(Mrule/2)
#    M1=M2=4
    M3=1
    network_structures=[para_num,M1,M2,M3]
    try:
        best_arg,elbo=batch_trainning(x_train,y_train,x_test,y_test,B,S,network_structures,epislon=3,mu=0,sigma=1.5,mu_p=0.0,sigma_p=1.8,lr=1,lr_s=0.02,bayesian_init=False)
    except:
        continue
    pred_prob,auc_temp=results_plot(best_arg)
    auc_list2.append(auc_temp)
    elbo_list2.append(elbo)
# Out:
# accuracy is 0.62
# accuracy is 0.74
# accuracy is 0.62
# accuracy is 0.7
# accuracy is 0.62
# accuracy is 0.64
# accuracy is 0.52
# accuracy is 0.62
# accuracy is 0.64
# accuracy is 0.6
# accuracy is 0.56
# accuracy is 0.72
# accuracy is 0.64
# accuracy is 0.58
# accuracy is 0.68
# accuracy is 0.62
# accuracy is 0.6
# accuracy is 0.58
# accuracy is 0.58
# accuracy is 0.76

# %%
pd.DataFrame(elbo_list2).to_csv('elbo_list2.csv')

# %%
pd.DataFrame(elbo_list2).T.plot()

# %%
pd.DataFrame(auc_list2).to_csv('auc_list2.csv')

# %%
sns.distplot(auc_list2)
